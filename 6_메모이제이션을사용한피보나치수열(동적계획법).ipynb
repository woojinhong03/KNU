# %% [markdown]
# <a href="https://colab.research.google.com/github/woojinhong03/KNU/blob/main/6_%EB%A9%94%EB%AA%A8%EC%9D%B4%EC%A0%9C%EC%9D%B4%EC%85%98%EC%9D%84%EC%82%AC%EC%9A%A9%ED%95%9C%ED%94%BC%EB%B3%B4%EB%82%98%EC%B9%98%EC%88%98%EC%97%B4(%EB%8F%99%EC%A0%81%EA%B3%84%ED%9A%8D%EB%B2%95).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())

dp = [0] * 91
dp[0], dp[1] = 0, 1

for i in range(2, n+1):
    dp[i] = dp[i-1] + dp[i-2]

print(dp[n])
# Out:
# 17
# 1597
