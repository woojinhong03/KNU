# %% [markdown]
# <a href="https://colab.research.google.com/github/woojinhong03/KNU/blob/main/4_%EB%91%90%EB%B0%B0%EC%97%B4%EC%9D%98%EC%9B%90%EC%86%8C%EA%B5%90%EC%B2%B4(%EC%A0%95%EB%A0%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
_, k = map(int, input().split())
a = sorted(list(map(int, input().split())))
b = sorted(list(map(int, input().split())),reverse=True)

a[:k] = b[:k]
print(sum(a))
# Out:
# 5 3
# 1 2 5 4 3
# 5 5 6 6 5
# 26

# %%
_, k = map(int, input().split())
a = sorted(list(map(int, input().split())))
b = sorted(list(map(int, input().split())),reverse=True)

for i in range(k):
    if a[i] < b[i]:
        a[i] = b[i]

print(sum(a))
# Out:
# 5 3
# 1 2 5 4 3
# 5 5 6 6 5
# 26
